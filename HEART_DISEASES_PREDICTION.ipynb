# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the csv data to a pandas Dataframe
heart_data = pd.read_csv('/content/heart.csv')

# %%
# print first 5 rows of the dataset
heart_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ad37a2072b2b> in <module>()
#       1 # print first 5 rows of the dataset
# ----> 2 heart_data.head()
#
# NameError: name 'heart_data' is not defined

# %%
# print last 5 rows of the dataset
heart_data.tail()

# %%
# number of rows and columns in the dataset
heart_data.shape

# %%
# getting some info about the data
heart_data.info()

# %%
# checking for missing value
heart_data.isnull().sum()

# %%
# statistical measure of the data
heart_data.describe()

# %%
# checking the distribution of Target  Variable
heart_data['target'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5fe268cd50b4> in <module>()
#       1 # checking the distribution of Target  Variable
# ----> 2 heart_data['target'].value_counts()
#
# NameError: name 'heart_data' is not defined

# %%
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-01d76112cb2b> in <module>()
# ----> 1 X = heart_data.drop(columns='target', axis=1)
#       2 Y = heart_data['target']
#
# NameError: name 'heart_data' is not defined

# %%
print(X)
print(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7f37a9e12cb7> in <module>()
# ----> 1 print(X)
#       2 print(Y)
#
# NameError: name 'X' is not defined

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-556260bb10e1> in <module>()
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
#
# NameError: name 'X' is not defined

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ced9ad7b4c10> in <module>()
# ----> 1 print(X.shape, X_train.shape, X_test.shape)
#
# NameError: name 'X' is not defined

# %%
model = LogisticRegression()

# %%
# training the LogisticRegression model with Training Data
model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-056ce990c25c> in <module>()
#       1 # training the LogisticRegression model with Training Data
# ----> 2 model.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7f6bac6f612f> in <module>()
#       1 # accuracy on training data
# ----> 2 X_train_prediction = model.predict(X_train)
#       3 training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
print('Accuracy on Training data : ',training_data_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b3252153c839> in <module>()
# ----> 1 print('Accuracy on Training data : ',training_data_accuracy)
#
# NameError: name 'training_data_accuracy' is not defined

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-491d9fb2c6b2> in <module>()
#       1 # accuracy on test data
# ----> 2 X_test_prediction = model.predict(X_test)
#       3 test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
#
# NameError: name 'X_test' is not defined

# %%
print('Accuracy on Test data : ',test_data_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ad30a40bd2c9> in <module>()
# ----> 1 print('Accuracy on Test data : ',test_data_accuracy)
#
# NameError: name 'test_data_accuracy' is not defined

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-15-f4bc4e6da8a5> in <module>()
#       7 input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
#       8
# ----> 9 prediction = model.predict(input_data_reshaped)
#      10 print(prediction)
#      11
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     403             this class would be predicted.
#     404         """
# --> 405         check_is_fitted(self)
#     406
#     407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
