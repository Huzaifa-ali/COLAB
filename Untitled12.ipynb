# %%
class Person:

  def myfunc(self):
    print("Hello my name  ")

p1 = Person()

# %%
p1.myfunc()
# Out:
# Hello my name

# %%
class Person1:
  def __init__(self, name, age):
    self.name = name
    self.age = age

# %%
p5 = Person1(11,14)
p5.name
# Out:
# '11'

# %%
p4.age = 20

# %%
p4.age
# Out:
# 20

# %%
del p4.age

# %%
p4.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-09bd1b719cbd> in <module>()
# ----> 1 p4.age
#
# AttributeError: 'Person1' object has no attribute 'age'

# %%
del p4

# %%
p4.name = 'simra'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-7f8082fcbd9d> in <module>()
# ----> 1 p4.name = 'simra'
#
# NameError: name 'p4' is not defined

# %%
p4.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-ab4369a365b9> in <module>()
# ----> 1 p4.name
#
# NameError: name 'p4' is not defined

# %%
p4.name = 1313

# %%
p4.name
# Out:
# 1313

# %%
class Person44:
  pass

# %% [markdown]
# single inheritance

# %%
# parent class
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(f'My first name is {self.firstname} and my last name is {self.lastname}')

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()

# %%
class Student(Person):
  pass

# %% [markdown]
# Multi level inheritance

# %%
# parent class
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(f'My first name is {self.firstname} and my last name is {self.lastname}')

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()
# Out:
# My first name is John and my last name is Doe

# %%
class Student(Person):
  pass

# %% [markdown]
# in student class we have all the properties of student class along with person class

# %%
class tution(Student):
  pass

# %%
test1 = tution('dwayne','johnson')

# %%
test1.printname()
# Out:
# My first name is dwayne and my last name is johnson

# %% [markdown]
# method overriding

# %%
# parent class
class teacher:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(f'My first name is {self.firstname} and my last name is {self.lastname}')

#Use the Person class to create an object, and then execute the printname method:

# %%
# child class 
class Student(teacher):
  def __init__(self, fname, mname, lname):
    self.firstname = fname
    self.middlename = mname
    self.lastname = lname

# %% [markdown]
# method overriding

# %%
test1 = Student('Muhammad','Huzaifa','Ali')
test1.printname()
# Out:
# My first name is Muhammad and my last name is Ali

# %% [markdown]
# Super()

# %%
# parent class/base class
class teacher:
  a = 5
  b = 'training'
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(f'My first name is {self.firstname} and my last name is {self.lastname}')

# %%
test2 = teacher('naruto','uzumaki')
test2.a
# Out:
# 5

# %%
# child class 
class Student(teacher):
  def __init__(self, fname, mname, lname, year):
    super().__init__(fname, lname)
    self.middlename = mname
    self.graduationyear = year
  def printname(self):
    print(f'Welcome {self.firstname} {self.middlename} {self.lastname} to the class {self.graduationyear}')

# %%
test1 = Student('Muhammad','Huzaifa','Ali',2015)

# %%
test1.graduationyear
# Out:
# 2015

# %%
test2 = Student('Simra','_','Rehman',2019)
test2.printname()
# Out:
# Welcome Simra _ Rehman to the class 2019

# %%
test3 = teacher('Simra','Rehman')
test3.printname()
# Out:
# My first name is Simra and my last name is Rehman

# %% [markdown]
# Multiple inheritance

# %%
class principle:
  a = 5
  b = 'training'
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(f'My first name is {self.firstname} last name is {self.lastname}')

# %%
class teacher:
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
  def printname(self):
    print(f'My first name is {self.firstname} and my last name is {self.lastname}')

# %%
class Student(principle,teacher):
  def __init__(self, fname, mname, lname, year):
    super().__init__(fname, lname)
    self.middlename = mname
    self.graduationyear = year
  def abc(self):
    print(f'Welcome {self.firstname} {self.middlename} {self.lastname} to the class {self.graduationyear}')

# %%
test = Student('Simra','_','Rahman',2020)

# %%
test.printname()
# Out:
# My first name is Simra last name is Rahman

# %% [markdown]
# Hierarical Inheritance

# %%
class principle:
  a = 5
  b = 'training'
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(f'My first name is {self.firstname} last name is {self.lastname}')

# %%
class teacher(principle):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
  def printname(self):
    print(f'My first name is {self.firstname} and my last name is {self.lastname}')

# %%
class Student(principle):
  def __init__(self, fname, mname, lname, year):
    super().__init__(fname, lname)
    self.middlename = mname
    self.graduationyear = year
  def abc(self):
    print(f'Welcome {self.firstname} {self.middlename} {self.lastname} to the class {self.graduationyear}')

# %%
class tutionteacher(principle):
  pass

# %%
test2 = tutionteacher('madara','uchiha')
test2.printname()
# Out:
# My first name is madara last name is uchiha

# %%
test3 = Student('ghost','Of','uchiha',2020)
test3.a
# Out:
# 5

# %% [markdown]
# Polymorphism

# %%
# len() function show the length 
# Python program to demonstrate in-built poly-
# morphic functions
 
# len() being used for a string
print('the length of word geeks is :',len("geeks"))
 
# len() being used for a list
print('The length of list is :',len([10, 20, 30]))
# Out:
# the length of word geeks is : 5
# The length of list is : 3

# %%
# A simple Python function to demonstrate
# Polymorphism
 
def add(w,x, y=0, z = 0):
    return w + x + y + z
 
# Driver code
print('The sum of 2 numbers',add(2, 3))
print('The sum of 3 numbers',add(2, 3, 4))
print('The sum of 4 numbers',add(2, 3, 4, 5))
# Out:
# The sum of 2 numbers 5
# The sum of 3 numbers 9
# The sum of 4 numbers 14

# %% [markdown]
#  Polymorphism in Class Methods

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        print(f"I am a cat. My name is {self.name}. I am {self.age} years old.")

    def make_sound(self):
        print("Meow")


class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        print(f"I am a dog. My name is {self.name}. I am {self.age} years old.")

    def make_sound(self):
        print("Bark")


cat1 = Cat("Kitty", 2.5)
dog1 = Dog("Fluffy", 4)
cat2 = Cat('Max',3)


for animal in (cat1, dog1, cat2):
    animal.make_sound()
    animal.info()
    animal.make_sound()
# Out:
# Meow
# I am a cat. My name is Kitty. I am 2.5 years old.
# Meow
# Bark
# I am a dog. My name is Fluffy. I am 4 years old.
# Bark
# Meow
# I am a cat. My name is Max. I am 3 years old.
# Meow

# %% [markdown]
# Polymorphism and Inheritance

# %%
from math import pi

class Shape:
    def __init__(self, name):
        self.name = name

    def area(self):
        pass

    def fact(self):
        return "I am a two-dimensional shape."

    def __str__(self):
        return self.name

class Square(Shape):
    def __init__(self, length):
        super().__init__("Square")
        self.length = length

    def area(self):
        return self.length**2

    def fact(self):
        return "Squares have each angle equal to 90 degrees."

class Circle(Square):
    def __init__(self, radius):
        super().__init__("Circle")
        self.radius = radius
    def area(self):
        return pi*self.radius**2




a = Square(4)
b = Circle(7)
# print(b)
# print(b.fact())
# print(a.fact())
# c = Shape('Na')
# c.fact()
b.fact()
# Out:
# 'Squares have each angle equal to 90 degrees.'

# %% [markdown]
# Method Overloading

# %%
#Program to illustrate method overloading
class edpresso:
    def Hello(self, name=None):
        if name is not None:
            print('Hello ' + name)
        else:
            print('Hello ')
            
# Create an instance/object
obj = edpresso()
    
# Call the method
print(obj.Hello())
    
# Call the method with a parameter
print(obj.Hello('Kadambini'))
# Out:
# Hello
# None
# Hello Kadambini
# None

# %%
# First product method.
# Takes two argument and print their
# product
def product(a, b):
    p = a * b
    print(p)
      
# Second product method
# Takes three argument and print their
# product
def product(a, b, c):
    p = a * b*c
    print(p)
  
# Uncommenting the below line shows an error    
# product(4, 5)
  
# This line will call the second product method
product(4, 5, 5)

# %% [markdown]
# operator overloading

# %%
class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y


p1 = Point(1, 2)
p2 = Point(2, 3)
print(p1+p2)
# print(type(p1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-a58594c2a2c2> in <module>()
#       9
#      10 #print(p1+p2)
# ---> 11 print(p1.__add__(p2))
#      12 # print(type(p1))
#
# AttributeError: 'Point' object has no attribute '__add__'

# %% [markdown]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-ed03979e3cc5> in <module>()
#       7 p1 = Point(1, 2)
#       8 p2 = Point(2, 3)
# ----> 9 print(p1+p2)
#      10 # print(type(p1))
#
# TypeError: unsupported operand type(s) for +: 'Point' and 'Point'

# %%
class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __str__(self): # special function
        return "({0}, {1})".format(self.x, self.y)


p1 = Point(2, 3)
print(p1)
# Out:
# (2, 3)

# %%
print(str(p1))
print(type(str(p1)))
print(format(p1))
print(type(format(p1)))
# Out:
# (2, 3)
# <class 'str'>
# (2, 3)
# <class 'str'>

# %%
class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __str__(self):
        return "({0},{1})".format(self.x, self.y)

    def __add__(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x, y)

    def __sub__(self, other):
        x = self.x - other.x
        y = self.y - other.y
        return Point(x, y)

    def __mul__(self, other):
        x = self.x * other.x
        y = self.y * other.y
        return Point(x, y)

    def __truediv__(self, other):
        x = self.x / other.x
        y = self.y / other.y
        return Point(x, y)
    def __lt__(self, other):
        self_mag = (self.x ** 2) + (self.y ** 2)
        other_mag = (other.x ** 2) + (other.y ** 2)
        return self_mag < other_mag
        
# if p1 + p2
# x = 1 + 2 = 3
# y = 2 + 3 = 5
# if p2 + p1
# x = 2 + 1 = 3
# y = 3 + 2 = 5

# if p1 - p2
# x = 1 - 2 = -1
# y = 2 - 3 = -1
# if p2 - p1
# x = 2 - 1 = 1
# y = 3 - 2 = 1

p1 = Point(1, 2)
p2 = Point(2, 3)
print('Doing p1 p2')
print('The sum of two numbers are : ',p1+p2)
print('The difference of two numbers are : ',p1-p2)
print('The Product of two numbers are : ',p1*p2)
print('The Division of two numbers are : ',p1/p2)
print('p1 is less than p2? : ',p1<p2)
print('-----------------------------------')
print('Doing p2 p1')
print('The sum of two numbers are : ',p2+p1)
print('The difference of two numbers are : ',p2-p1)
print('The Product of two numbers are : ',p2*p1)
print('The Division of two numbers are : ',p2/p1)
print('p2 is less than p1? : ',p2<p1)
# Out:
# Doing p1 p2
# The sum of two numbers are :  (3,5)
# The difference of two numbers are :  (-1,-1)
# The Product of two numbers are :  (2,6)
# The Division of two numbers are :  (0.5,0.6666666666666666)
# p1 is less than p2? :  True
# -----------------------------------
# Doing p2 p1
# The sum of two numbers are :  (3,5)
# The difference of two numbers are :  (1,1)
# The Product of two numbers are :  (2,6)
# The Division of two numbers are :  (2.0,1.5)
# p2 is less than p1? :  False
# 1

# %% [markdown]
# Encapsulation

# %% [markdown]
# Protected Memeber

# %%
# Python program to
# demonstrate protected members

# Creating a base class
class Base:
	def __init__(self):

		# Protected member
		self._a = 2

# Creating a derived class
class Derived(Base):
	def __init__(self):

		# Calling constructor of
		# Base class
		Base.__init__(self)
		print("Calling protected member of base class: ",
			self._a)

		# Modify the protected variable:
		self._a = 3
		print("Calling modified protected member outside class: ",
			self._a)

obj1 = Derived()

obj2 = Base()

# Calling protected member
# Can be accessed but should not be done due to convention
print("Accessing protected member of obj1: ", obj1._a)

# Accessing the protected variable outside
print("Accessing protected member of obj2: ", obj2._a)
# Out:
# Calling protected member of base class:  2
# Calling modified protected member outside class:  3
# Accessing protected member of obj1:  3
# Accessing protected member of obj2:  2

# %%
# Python program to
# demonstrate protected members

# Creating a base class
class Base:
	def __init__(self):

		# Protected member
		self._a = 2

obj = Base()

# %% [markdown]
# Private Member

# %%
# Python program to
# demonstrate private members
 
# Creating a Base class
 
 
class Base:
    def __init__(self):
        self.a = "GeeksforGeeks"
        self.__c = "GeeksforGeeks1"
 
# Creating a derived class
class Derived(Base):
    def __init__(self):
 
        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling private member of base class: ")
        print(self.__c)
 
 
# Driver code
obj1 = Base()
print(obj1.a)
# print(obj1.c)
obj2 = Derived()
 
# Uncommenting print(obj1.c) will
# raise an AttributeError
 
# Uncommenting obj2 = Derived() will
# also raise an AtrributeError as
# private member of base class
# is called inside derived class
# Out:
# GeeksforGeeks
# Calling private member of base class:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-55a596919f72> in <module>()
#      25 print(obj1.a)
#      26 # print(obj1.c)
# ---> 27 obj2 = Derived()
#      28
#      29 # Uncommenting print(obj1.c) will
#
# <ipython-input-23-55a596919f72> in __init__(self)
#      18         Base.__init__(self)
#      19         print("Calling private member of base class: ")
# ---> 20         print(self.__c)
#      21
#      22
#
# AttributeError: 'Derived' object has no attribute '_Derived__c'

# %% [markdown]
# https://pynative.com/python-encapsulation/
