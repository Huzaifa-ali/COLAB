# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
traffic = pd.read_csv('/content/traffic-speed[1].csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9234e387e201> in <module>
# ----> 1 traffic = pd.read_csv('/content/traffic-speed[1].csv')
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
traffic.head()

# %%
traffic.info()

# %%
traffic.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5336d6ca1a01> in <module>
# ----> 1 traffic.describe()
#
# NameError: name 'traffic' is not defined

# %%
traffic.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-da29f074557d> in <module>
# ----> 1 traffic.isnull().sum()
#
# NameError: name 'traffic' is not defined

# %%
traffic.speed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3bbef05fa85f> in <module>
# ----> 1 traffic.speed
#
# NameError: name 'traffic' is not defined

# %%
traffic.shape
# Out:
# (3556, 7)

# %%
for col in traffic:
  print(traffic[col].unique())
# Out:
# [2019 2020 2021 2022]
# ['Jan' 'Feb' 'Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']
# ['Passenger' 'Freight' 'All']
# ['AM' 'PM']
# ['Urban' 'Rural']
# [1 2 3 4 5 6 7]
# [54.5 49.6 27.5 24.9 19.8 21.3 22.  66.7 61.7 52.1 48.1 45.2 32.  31.6
#  54.  49.2 25.7 23.3 19.5 20.9 68.  62.9 53.5 45.5 29.  30.8 52.6 48.
#  26.8 24.7 19.7 22.9 66.4 61.2 51.7 47.8 45.1 13.  23.7 25.1 19.1 21.
#  67.7 62.5 53.  47.7 47.  25.  54.3 49.3 27.3 20.  21.2 23.5 67.6 62.7
#  52.7 47.2 44.6 19.  25.9 51.5 47.6 22.7 19.2 20.6 18.6 68.2 63.  53.4
#  46.3 18.  31.9 53.9 48.9 27.1 19.6 67.8 47.9 43.8 42.9 31.2 51.  47.1
#  20.1 19.4 62.8 53.2 45.  26.4 53.8 24.4 19.3 22.8 22.1 62.6 52.4 44.
#  14.7 29.9 49.9 24.5 22.6 18.7 20.4 18.5 67.3 62.4 46.6 43.  28.5 54.8
#  50.3 28.4 25.5 19.9 21.5 22.5 67.5 52.8 48.3 32.3 46.2 20.3 67.  62.
#  52.5 43.1 37.6 57.  29.5 26.1 24.  23.8 53.1 48.7 44.4 35.  29.2 51.2
#  25.6 62.1 46.  42.7 40.3 55.2 50.5 27.8 25.2 23.1 52.3 47.5 43.5 50.
# ...
