# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
accident = pd.read_csv('/content/accident[1].csv')

# %%
accident.head()
# Out:
#    index  accident_id  ST_CASE  VE_TOTAL  VE_FORMS  PEDS  PERSONS  COUNTY  \
# 0      0   2012040001    40001         1         1     0        1      19
# 1      1   2012040002    40002         1         1     0        2      25
# 2      2   2012040003    40003         1         1     1        0      13
# 3      3   2012040004    40004         2         2     0        2      13
# 4      4   2012040005    40005         2         2     0        4      19
#
#   county_name  CITY  ... A_POLPUR  a_polour_lit  A_POSBAC  \
# 0        PIMA     0  ...        2   Other Crash         1
# 1     YAVAPAI    90  ...        2   Other Crash         1
# 2    MARICOPA   370  ...        2   Other Crash         2
# 3    MARICOPA   190  ...        2   Other Crash         2
# 4        PIMA   530  ...        2   Other Crash         3
#
#                               a_posbac_lit  A_DIST   a_dist_lit  A_DROWSY  \
# 0   Driver With Positive BAC Testing Crash       2  Other Crash         2
# ...

# %%
accident.shape
# Out:
# (1860, 80)

# %%
accident.describe()
# Out:
#              index   accident_id       ST_CASE     VE_TOTAL     VE_FORMS  \
# count  1860.000000  1.860000e+03   1860.000000  1860.000000  1860.000000
# mean    929.500000  2.014036e+09  40403.498925     1.384946     1.368817
# std     537.080069  1.437050e+06    236.785498     0.619904     0.602573
# min       0.000000  2.012040e+09  40001.000000     1.000000     1.000000
# 25%     464.750000  2.013040e+09  40203.000000     1.000000     1.000000
# 50%     929.500000  2.014040e+09  40399.500000     1.000000     1.000000
# 75%    1394.250000  2.015041e+09  40601.000000     2.000000     2.000000
# max    1859.000000  2.016041e+09  40880.000000     6.000000     5.000000
#
#               PEDS      PERSONS       COUNTY         CITY          DAY  ...  \
# count  1860.000000  1860.000000  1860.000000  1860.000000  1860.000000  ...
# mean      0.255914     2.231183    17.148925   224.463441    15.247849  ...
# std       0.486606     1.770081    56.230926   709.181094     8.868981  ...
# ...

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860 entries, 0 to 1859
# Data columns (total 80 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           1860 non-null   int64
#  1   accident_id     1860 non-null   int64
#  2   ST_CASE         1860 non-null   int64
#  3   VE_TOTAL        1860 non-null   int64
#  4   VE_FORMS        1860 non-null   int64
#  5   PEDS            1860 non-null   int64
#  6   PERSONS         1860 non-null   int64
#  7   COUNTY          1860 non-null   int64
#  8   county_name     1860 non-null   object
#  9   CITY            1860 non-null   int64
#  10  city_name       1860 non-null   object
#  11  DAY             1860 non-null   int64
#  12  MONTH           1860 non-null   int64
#  13  YEAR            1860 non-null   int64
#  14  HOUR            1860 non-null   int64
#  15  MINUTE          1860 non-null   int64
#  16  NHS             1860 non-null   int64
# ...

# %%
accident.duplicated().sum()
# Out:
# 0

# %%
accident.isnull().sum()
# Out:
# index             0
# accident_id       0
# ST_CASE           0
# VE_TOTAL          0
# VE_FORMS          0
#                  ..
# a_dist_lit        0
# A_DROWSY          0
# a_drowsy_lit      0
# INDIAN_RES        0
# indian_res_lit    0
# Length: 80, dtype: int64
